# %%
## Text Adventure Endgame 
#Setup
from IPython.display import YouTubeVideo

#Define colors to make printed text nicer
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

#Define the New Hope function that changes the outcome of the story
def a_new_hope():
    print(f"""\n-It's been hours of fighting and Thanos is beating the three of you.
    \n- {user_name} Stark is lying hurt in the ground when he see's Captain America weild Mjolnir.""")
    print(color.BOLD + """\n- Thor: 'I knew it!'\n\n""" + color.END)
    print("- When the three of you get together to go for another round, you hear a sudden:")
    print(color.BOLD + f"""\n'Hey Cap, you read me? On your Left'""" + color.END)
    print(f"""\n\nAnd as portals begin to open you see Doctor Strange descend in. He is joined by Drax, Mantis, Star Lord, and Spider-Man.
    \n\nEveryone watches in confusion and awe as more and more heroes arrive from all corners of the universe.
    \n\nNearly every hero has magically been transported to the battlefield to face Thanos' army.\n""")
    print(color.BOLD + "Captain America: AVENGERS!!! ... Assemble" + color.END)

#Define the final script and story lines
def Final_encounter():
    print(f"""While the Avengers army tries to fight through Thanos' army in order to reach the Quantum Tunnel
    and send the Infinity Gauntlet back in time, A bright light of thundering energy comes surging down 
    as Carol Danvers flies through the ship, and it results in an explosion and the ship crash-landing in the lake.""")
    print(color.BOLD +"""\nPeter Parker: 'Hi. I'm– Peter Parker.'
    \nCaptain Marvel: 'Hey, Peter Parker. You got something for me?' (Peter gives Carol the Gauntlet)""" + color.END) 
    print("""\n\nCarol Danvers then starts flying towards the van with the Gauntlet, flying past enemies and going through enemy blockades 
    that are in her way with ease. Thanos, seeing this, starts running to Carol Danvers, 
    but is stopped by Pepper, Shuri and The Wasp, who blast him backwards. 
    Thanos, after seeing Carol Danvers fly past him, throws his double sword at the van, 
    destroying it and the quantum realm tunnel, throwing Carol Danvers backwards and losing her grip on the Gauntlet, which falls to the ground.""")

#Define actions to later use in user input
yes_no = ["Yes", "No"]
last_decision = ["attack him", "take the stones", "run", "a", "A", "b", "B", "c", "C"]
user_attack = 3
attack = ["Punch", "punch", "Lazer", "lazer", "Team attack with Captain America and Thor", "team attack", "a", "A", "b", "B", "c", "C"]
def Iron_man():
    print(color.RED + """
             :~7~::!~:
           ..7B&GJ5&B7.                                                                             
          ^?BPB&&B#@&G~                                                                             
        .^?B&#GB@#P#&BY.                                                                            
        ~BBPB&B5#@#B@&B!                      .:^~?5YJ^:..                                          
        .~#&BB&#P&&#&&#P^  .:~~.             .~77!!YP?::^:.                                         
          :G&BP#GGGGB#BBJ.~P&@&?.            ^~^!~^:.....^.                                         
           .Y#G57^:^!JPPGB&@&B7.            .7~~Y7!!~^:^~7^                                         
            :Y5^.    .7?B&&B7.              :5^7?!~~~:..:!!.                                        
             :J7:   .^JG##B?YJ!.            .Y7!5Y7!^. .!5~                                         
              :?YJ77JPB#BB#JB&&#!.       ....~77JBY7!^:7GP.                                         
               :JB&##&&&&&#B##&&P!JYPP5YJJPG##BGBBG7?77J5?.                                         
               .7G##&&&&&@&&BBB##Y#&#B#&&#PB&&&##&&&&&&BBGGPY?^..                                   
                .!J#@@@@@@@@&#BB#5?!~?!?5###&&&&##&##&&&#5#@&##BY.                                  
��⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                 ⠀⠀⢀⣴⡿⠟⠋⠉⣼⣿⡿⣿⣿⡇⠀⢀⣤⣤⠀⢠⣤⣤⢀⣤⣤⣤⣤⡄⣠⣤⡀⢀⣤⣤⠀⣀⣤⣤⣤⣤⡀⠀⣠⣤⣤⣤⡄⢀⣤⣤⣤⣤⣄⡀⢀⣠⣤⣤⣤⡄
                 ⠀⣰⣿⠋⠀⠀⠀⣼⣿⡿⠁⣿⣿⡇⠀⢸⣿⣿ ⣿⣿⠇⣼⣿⡿⠿⠿⢡⣿⣿⡇⣸⣿⡿⢰⣿⣿⠿⠿⠿⠀⢰⣿⣿⠿⠿⠇⣾⣿⡟⢻⣿⣿⠇⣾⣿⡿⠿⠿⠃
                 ⢰⣿⠁⠀⠀⠀⣸⣿⣿⠃⠀⣿⣿⡇⠀⣸⣿⣏⣾⣿⠏⢠⣿⣿⠃⠀⠀⣼⣿⣿⣇⣿⣿⠃⣾⣿⡇⠀⠀⠀⠀ ⣾⣿⡏⠀⠀⢰⣿⣿⠁⣸⣿⡟⢰⣿⣿⠁⠀⠀⠀
                 ⣿⡇⠀⠀⠀⣰⣿⣿⠃⠀⠀⠻⣿⡇⠀ ⣿⣿⣿⡟⠀ ⣾⣿⣿⡿ ⢰⣿⣿⣿⣿⣿⡏⢸⣿⡿⢠⣿⣿⡟⢸⣿⣿⣿⣿⠃⣿⣿⣷⣶⣿⡿⠃⣿⣿⣿⣶⣶⠀⠀
                 ⣿⡇⠀⠀⣰⣿⣿⣿⣶⣶⣶⣷⣌⠃⢠⣿⣿⣿⡿⠀⢰⣿⣿⠉⠁ ⣾⣿⢿⣿⣿⣿⢁⣿⣿⠇⢨⣿⣿⢁⣿⣿⡏⠉⠉⣸⣿⡿⠉⣿⣿⡇⠀⠉⠉⣹⣿⡿⠀⠀
                 ⢹⣿⡀⣰⣿⣿⡿⠿⠿⠿⢿⣿⠟⡁⢸⣿⣿⡿⠁⠀⣿⣿⣯⣤⡄⢸⣿⡿⢸⣿⣿⡏⣸⣿⣿⣀⣼⣿⡇⣸⣿⣿⣤⣤⢀⣿⣿⠇⢰⣿⣿⠁⣠⣤⣤⣿⣿⠇⠀⠀
                 ⠀⠻⢱⣿⣿⡿⠀⠀⠀⠀ ⠈⠵⠾⠇ ⠿⠿⠀  ⠸⠿⠿⠿⠿⠁⠿⠿⠃⠈⠿⠿⠀⠹⠿⠿⢿⣿⠿⠠⠿⠿⠿⠿⠏⠼⠿⠿⠀⠿⠿⠇⠠⠿⠿⠿⠿⠟⠀⠀⠀
                 ⠀⢠⣿⣿⡿⣁⡀⠀⠀⠀⠀ ⢀⣠⣴⡿⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                 ⢠⣿⣿⣿⠃⠛⠻⠿⠿⠿⠿⠿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    """+ color.END)

def snap():
    print(color.BOLD + """
                                                                                                    
                                        .^~7:                                                       
                                     .YGBBG&@B:                                                     
                                    :BBBBGP#&@&:                                                    
                                   .G#GGG5G#&@@#                                                    
                                   JBPPPPPB#&&&&7                                                   
                                  ~55555JG###&&BJ                                                   
                                 ?5G5Y5JJB&&&&&#J                                                   
                                 7PGJ7??5#&&&&&#5                                                   
                                 # ?PP7~~75B&&&&#GG:                                                  
                                 JPJ^^:~JB#&&&&PG:                                                  
                                .YJ!::^?PB#&&&#PB.                                                  
                    ^P##GYGG&@#BP5P5#@G&@@@&&BP#&&&#######BBBB###&&#&&&&&&@&&&@@&&&&&@@@@&&&@5      
                    YG&P#GJP@@B#&&BG&@#&@@@&&&PB&&&#######&&&&#&####&&&&&&&&&&@@@&@@@@&@@@&@@&      
                   ^B##GPG#&@@##5YBB&@#&@@@&&&PG&&###&&&#&#&&&&######&&&&&&&@#&@@&&&&@&@@&@&@@:     
                   YB&P#J?5&@&&@@@#P&@#&@@@&&&BG#&&##&&&&&&&&&&&&######&&&#&@&&@@@&&&@&&@@&&@@?     
                  :PB#BGBGP@@&&#B55B&@#&@@@&&@&G#&&###&&&&&&&&&&&##&&&&###&&@@#@@@&&@@&&@@@@&@G     
                  ?5#B&5&#5&@#BY5GG#@@#&@@@&@@@GB&&&&##&&&&&&&&&&&&&&&&###&&@@#&@@&##&&&@@@&@@#      
    """)

def I_am_Ironman():
    print(color.BOLD + """
                                       ⠀⠀⠀⠀⠀⠀⠀⣀⣤⡴⣶⣶⣿⣿⣿⣿⣿⣿⣷⣶⢶⣤⣄⡀⠀⠀⠀⠀⠀⠀
                                      ⠀⠀⠀⢀⣤⡶⠛⠉⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠀⠉⠛⢷⣤⡀⠀⠀⠀
                                      ⠀⠀⣴⡟⠉⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⠁⠀⠀⠀⠀⠈⠻⣦⠀⠀
                                      ⠀⢠⣿⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⡇⠀
                                      ⠀⢸⡿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣧⠀
                                      ⠀⣿⡇⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⢸⣿⠀
                                      ⠀⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢸⣿⡀
                                      ⢰⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⡇
                                      ⢸⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣿⡇
                                      ⢸⣿⡇⢸⣿⣿⣶⣶⣦⣤⣤⣄⣀⣀⣀⣀⣠⣤⣤⣴⣶⣶⣾⣿⣇⣿⣧
                                      ⣿⡿⠙⢿⣇⡀⠀⠈⠉⢉⣽⡟⠛⠛⠛⠛⢻⣿⠉⠉⠉⠀⠀⣨⡿⢻⣿
                                      ⣿⡇⠀⠀⠉⠙⠛⠛⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠙⠛⠛⠋⠉⠸⣿
                                      ⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
                                      ⢿⣷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣾⣿
                                      ⠸⣿⣿⣦⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡠⠊⠀⣠⣿⣿⠇
                                      ⠀⢻⣿⣿⣷⡄⠈⠳⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠞⠁⢀⣴⣿⣿⡟⠀
                                      ⠀⠀⢻⣿⣿⣿⣆⠀⠙⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⠋⠀⢠⣾⣿⣿⡟⠀⠀
                                      ⠀⠀⠈⢿⣿⣿⣿⡆⠀⠘⣧⠀⠀⠀⠀⠀⠀⠀⠀⣰⠃⠀⢠⣿⣿⣿⣿⠁⠀⠀
                                      ⠀⠀⠀⠘⣿⣿⣿⣧⡀⢀⡾⠶⠶⠶⠶⠶⠶⠶⠶⢿⣄⢀⣸⣿⣿⣿⠇⠀⠀⠀
                                      ⠀⠀⠀⠀⢻⣿⣿⠃⠙⠋⠀⡄⠀⠀⠀⠀⠀⠀⢠⠀⠙⠟⠙⣿⣿⡟⠀⠀⠀⠀
                                      ⠀⠀⠀⠀⠀⠛⢿⣦⣄⠀⣠⣷⣴⣶⣿⣿⣷⣤⣾⣄⡀⣀⣴⡿⠟⠁⠀⠀⠀⠀
                                      ⠀⠀⠀⠀⠀⠀⠀⠈⠻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠉⠀⠀⠀⠀⠀⠀⠀
 """)


#First Stage
# Scene 1
Avengers()
user_name = input(prompt=f"""What is your name, Avenger?\n""")

#First user input to welcome to the story
user_play = ""
while user_play not in yes_no:
    user_play= input(prompt=f"""\nYou wake up and find yourself on top of a pile of dirt with an army of aliens rushing your way.\nYou look to the left and you see the Viking god, Thor, with the mighty Mjolnir in one hand and Storm Breaker 
    on the other. You look to your right and see Captain America weilding his shield and ready for battle.
    Thats when you look down and see you are wearing the Iron Man suit and hear Cap say\n\n"{user_name} are you ready for battle?\nyes/no\n\n""")
    if user_play == "yes":
        print(color.BOLD + f"""\n-{user_name} Stark: 'He doesn't have the stones yet'\n\n-Captain America: 'So we keep it that way'\n-Thor: 'You know it's a trap, right?'\n{user_name} Stark:'Yeah. And I don't much care.'"""+color.END)
        print("""\n\n ---------------------------You and your fellow Avengers launch an all out attack on Thanos---------------------------""")
        print(color.BOLD + f"""\n-Thanos: 'You could not live with your own failure. And where did that bring you? Back to me.
        I thought by eliminating half of life, the other half would thrive. But you’ve shown me that’s impossible.
        And as long as there are those that remember what was, there will always be those that are unable to accept what can be. They will resist.'
        \n-{user_name} Stark: 'Yep. We're all kinds of stubborn.'\n\n\n"""+color.END)
        Iron_man()
        break    
    elif user_play == "no":
        print(f"""\n- Captain America: '{user_name} what are you doing?! You can't \
        leave us here to fight alone!!!'\n You see Captain America and Thor getting\
        destroyed by Thanos and his army while you fly away kowing you failed humanity""")
        quit()
    else:
        print(color.BOLD+ f"""\n- Captain America: '{user_name}' we need you to decide, make sure to use 'yes' or 'no'"""+ color.END)

#Second Stage
# Scene 2
#Call a_new_hope() function that prints part of the story
a_new_hope()

print("""\n\n ----------------------------------------------------------------\
--------------------------------------------\n\n 
""")

print(color.BOLD+ f"""-Captain A.: '{user_name} We need you with us distracting Thanos while the rest return the Gauntlet back in time!""" + color.END)

#After three tries, the story continues as a "failed" attack regardless of the decitions. This is on purpose to create
#frustration from the user and feel like even the "toughest" attack fails.
while user_attack > 0:
    attack= input(prompt=f"""\nNow you find yourself fighting Thanos with Thor and Captain America,
    but success depends on your attacks\nchoose wisely in order to succeed.\n\nSelect "a" to Punch Thanos\nSelect "b" to user armour lazers\nSelect "c" to do a team attack with Captain America and Thor\n\n""")
    
    #Create IF statement
    if attack == "Punch" or attack == "a" or attack == "A" or attack == "punch":
        print(f"""\nYou go all out with your fists not waiting for Thor or Cap towards Thanos but he is to strong and knocked you out.""")
        user_attack -= 1
        print("\nYour attack didn't stop Thanos, what do you do now?")
   
    #Second condition    
    elif attack == "Lazer" or attack == "b" or attack == "B" or attack == "lazer":
        print(f"""\nThor bangs his 2 hammers together combined with his lightning. {user_name} Starks suit sucks up the energy and 
        \nshoots it out using his hands and his body. Thanos twirls his blade really fast to divert the energy.""")
        user_attack -= 1
        print("\nYour attack didn't stop Thanos, what do you do now?")
    
    #Third Condition
    elif attack == "Team attack with Captain America and Thor" or attack == "Team attack" or attack == "team attack" or attack == "C" or attack == "c":
        print(f"""\nCap tries to attack Thanos but is easily shielded away by the Mad Titan.
        \nThor's attack on Thanos is blocked by his sword. Thor is beaten and choked by Thanos, as he punches him.
        \nThor grabs Stormbreaker and uses it to bat Mjölnir to hit Thanos. Thanos uses {user_name} as a shield resulting in damage to his \nsystem.""")
        user_attack -=1
        print("\nYour attack didn't stop Thanos, what do you do now?")
  
    #Control Unexpected user input
    else:
        print("\n- Thor: C'mon Stark!!! We need you here!")

#When the user ends "The Battle" with Thanos, regardless of the decisions, the story continues.
#Outcome of the Battle
if user_attack ==0:
    print(color.BOLD + f"""\n- Allthoguh your efforts have been in vain, {user_name} looks at Dr. Strang
    \n-{user_name} Stark: 'Hey. You said one out of 14 million, we win, yeah? Tell me this is it.'
    \n- Dr. Strange: 'If I tell you what happens, it won't happen
    \n- {user_name} Stark: 'You better be right.'"""+ color.END)
    
    
#Stage 3
#Scene 3
print("""\n\n ----------------------------------------------------------------\
--------------------------------------------\n\n 
""")
Final_encounter()

print("""Thanos puts on the gauntlet, gamma radiation from the stones eating at him as he tries to snap, 
      but Carol Danvers arises again, and stops his fingers from snapping, opening up his hand.
      \n\nThanos pulls the Power Stone out of the Gauntlet and uses it in his free hand to hit Carol Danvers away.
      Stark looks in question at Strange, who simply raises one finger...\n\n""")

print(color.BOLD + """-Thanos:I am– inevitable."""+color.END)

snap()

#Get user input for the most important decision of the game and the story.
last_decision= input(prompt=color.END+ f"""{user_name} it's your time to save the world...\n\nSelect "a" to Attack Thanos\nSelect "b" to Take the Infinity Stones\nSelect "c" to fly away and try to save yourself...?\n\n"""+color.END)
    
if last_decision == "attack him" or last_decision == "a" or last_decision == "A":
        print("""Thanos snapped his fingers before you could touch him.
        You start seeing all the Avengers begin to fade and become dust.
        You turn to Spider Man:""")
        print(color.BOLD + """\n- Spider-Man: 'I don't want to go Mr. Stark'"""+ color.END)
        print("""\n You see Peter become dust just before it's your turn to go as well...""")
        print(color.BOLD + "GAME OVER" + color.END)
        quit()    
        
elif last_decision == "take the stones" or last_decision == "b" or last_decision == "B":
    print(color.BOLD + f"""\n- {user_name} Stark: 'And I am IRON MAN'""" + color.END)
    
    #Present the user with the Avengers Themesong to finalize the game while reading the final scene after the correct decision.
    print(color.BOLD+ "Play the following video for an inmersive/ chill-giving experience"+color.END)
    AvengersTheme= YouTubeVideo("F_mhWxOjxp4",height=600, width=500, start=120)
    display(AvengersTheme)
    
    I_am_Ironman()
    
    #ENDING
    print(f"""\n\n{user_name} Stark saved humanity and brought back everyone who had been 'Snaped' 5 years ago.
    Even if {user_name} didn't make it after the Snap, he will be remembered as the Hero that he is.""")
    
    print(color.BOLD+ f"""\n {user_name} Stark: That's the thing, that's the hero gig. Part of the journey is the end.\n
    What am I even trippin' for? Everything's gonna work out exactly the way it's supposed to.\n\n I love you 3,000."""+color.END)
    

elif last_decision == "run" or last_decision == "c" or last_decision == "C":
    print(f"""\n- Thanos snapped his fingers before you could try to fly away.
    You start seeing all the Avengers begin to fade and become dust, 
    Cap and Thor look up at you while they become dust and you fall to the ground just to join them in extinction""")
    print(color.BOLD + "GAME OVER" + color.END)
    quit()
    
else:
    print(f"""\n- {user_name} you have to do something""")


print("""\n\n\nThanks for playing Text Adventure Endgame, by Rafael de la Cajiga Leon
\nSource of dialogue: https://movies.fandom.com/wiki/Avengers:_Endgame/Transcript""")
# Out:
#                   ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#                  ⠀⠀⠀⠀⠀⣀⣤⣤⡄⣼⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#                  ⠀⠀⢀⣴⡿⠟⠋⠉⣼⣿⡿⣿⣿⡇⠀⢀⣤⣤⠀⢠⣤⣤⢀⣤⣤⣤⣤⡄⣠⣤⡀⢀⣤⣤⠀⣀⣤⣤⣤⣤⡀⠀⣠⣤⣤⣤⡄⢀⣤⣤⣤⣤⣄⡀⢀⣠⣤⣤⣤⡄
#                  ⠀⣰⣿⠋⠀⠀⠀⣼⣿⡿⠁⣿⣿⡇⠀⢸⣿⣿ ⣿⣿⠇⣼⣿⡿⠿⠿⢡⣿⣿⡇⣸⣿⡿⢰⣿⣿⠿⠿⠿⠀⢰⣿⣿⠿⠿⠇⣾⣿⡟⢻⣿⣿⠇⣾⣿⡿⠿⠿⠃
#                  ⢰⣿⠁⠀⠀⠀⣸⣿⣿⠃⠀⣿⣿⡇⠀⣸⣿⣏⣾⣿⠏⢠⣿⣿⠃⠀⠀⣼⣿⣿⣇⣿⣿⠃⣾⣿⡇⠀⠀⠀⠀ ⣾⣿⡏⠀⠀⢰⣿⣿⠁⣸⣿⡟⢰⣿⣿⠁⠀⠀⠀
#                  ⣿⡇⠀⠀⠀⣰⣿⣿⠃⠀⠀⠻⣿⡇⠀ ⣿⣿⣿⡟⠀ ⣾⣿⣿⡿ ⢰⣿⣿⣿⣿⣿⡏⢸⣿⡿⢠⣿⣿⡟⢸⣿⣿⣿⣿⠃⣿⣿⣷⣶⣿⡿⠃⣿⣿⣿⣶⣶⠀⠀
#                  ⣿⡇⠀⠀⣰⣿⣿⣿⣶⣶⣶⣷⣌⠃⢠⣿⣿⣿⡿⠀⢰⣿⣿⠉⠁ ⣾⣿⢿⣿⣿⣿⢁⣿⣿⠇⢨⣿⣿⢁⣿⣿⡏⠉⠉⣸⣿⡿⠉⣿⣿⡇⠀⠉⠉⣹⣿⡿⠀⠀
#                  ⢹⣿⡀⣰⣿⣿⡿⠿⠿⠿⢿⣿⠟⡁⢸⣿⣿⡿⠁⠀⣿⣿⣯⣤⡄⢸⣿⡿⢸⣿⣿⡏⣸⣿⣿⣀⣼⣿⡇⣸⣿⣿⣤⣤⢀⣿⣿⠇⢰⣿⣿⠁⣠⣤⣤⣿⣿⠇⠀⠀
#                  ⠀⠻⢱⣿⣿⡿⠀⠀⠀⠀ ⠈⠵⠾⠇ ⠿⠿⠀  ⠸⠿⠿⠿⠿⠁⠿⠿⠃⠈⠿⠿⠀⠹⠿⠿⢿⣿⠿⠠⠿⠿⠿⠿⠏⠼⠿⠿⠀⠿⠿⠇⠠⠿⠿⠿⠿⠟⠀⠀⠀
#                  ⠀⢠⣿⣿⡿⣁⡀⠀⠀⠀⠀ ⢀⣠⣴⡿⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#                  ⢠⣿⣿⣿⠃⠛⠻⠿⠿⠿⠿⠿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#
# What is your name, Avenger?
# Rafa
#
# ...
